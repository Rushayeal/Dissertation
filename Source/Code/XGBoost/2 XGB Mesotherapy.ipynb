# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import r2_score, explained_variance_score, max_error, mean_squared_error
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split

# load the sales data set
sales_data = pd.read_csv('../../../Data/SalesData.csv')
sales_data.head()

sales_data = sales_data[sales_data['Category'] == 'Mesotherapy'] 

pharmacy_onehot = pd.get_dummies(sales_data['Pharmacy'])

# concatenate the one-hot encoded categories with the original data
sales_data_encoded2 = pd.concat([sales_data, pharmacy_onehot], axis=1)

product_onehot = pd.get_dummies(sales_data['Product'])

# concatenate the one-hot encoded categories with the original data
sales_data_encoded3 = pd.concat([sales_data_encoded2, product_onehot], axis=1)

product_onehot = pd.get_dummies(sales_data['Location'])

# concatenate the one-hot encoded categories with the original data
sales_data_encoded = pd.concat([sales_data_encoded3, product_onehot], axis=1)

sales_data_encoded
# Out:
#             Date  Month  Quarter  Year  Qty       Product     Category  \
# 13     1-12-2015     12        4  2015    1  Injection 13  Mesotherapy
# 36      1-1-2016      1        1  2016    1  Injection 13  Mesotherapy
# 37      1-1-2016      1        1  2016    1  Injection 13  Mesotherapy
# 38      1-1-2016      1        1  2016    1  Injection 13  Mesotherapy
# 78      1-2-2016      2        1  2016    1  Injection 13  Mesotherapy
# ...          ...    ...      ...   ...  ...           ...          ...
# 67191   1-3-2022      3        1  2022    1  Injection 13  Mesotherapy
# 67428   1-3-2022      3        1  2022    1  Injection 13  Mesotherapy
# 67441   1-3-2022      3        1  2022    1  Injection 13  Mesotherapy
# 68019   1-3-2022      3        1  2022    1  Injection 13  Mesotherapy
# 68129   1-3-2022      3        1  2022    1  Injection 13  Mesotherapy
#
#           Pharmacy                    Location  Pharmacy 1  ...  \
# 13      Pharmacy 2          Outside London M25           0  ...
# 36      Pharmacy 2                   NorthWest           0  ...
# 37      Pharmacy 2          Outside London M25           0  ...
# 38      Pharmacy 2          Outside London M25           0  ...
# 78      Pharmacy 2         Scotland, Newcastle           0  ...
# ...            ...                         ...         ...  ...
# 67191   Pharmacy 9                      London           0  ...
# 67428   Pharmacy 9                      London           0  ...
# 67441   Pharmacy 9         Scotland, Newcastle           0  ...
# 68019   Pharmacy 1     Outside London the rest           1  ...
# 68129  Pharmacy 10  Ireland & Northern Ireland           0  ...
#
#        Brazil, USA, Blank, IE, Zimbabwe, Zurich  Ireland & Northern Ireland  \
# 13                                            0                           0
# 36                                            0                           0
# 37                                            0                           0
# 38                                            0                           0
# 78                                            0                           0
# ...                                         ...                         ...
# 67191                                         0                           0
# 67428                                         0                           0
# 67441                                         0                           0
# 68019                                         0                           0
# 68129                                         0                           1
#
#        London  NorthEast, Midlands  NorthWest  Outside London M25  \
# 13          0                    0          0                   1
# 36          0                    0          1                   0
# 37          0                    0          0                   1
# 38          0                    0          0                   1
# 78          0                    0          0                   0
# ...       ...                  ...        ...                 ...
# 67191       1                    0          0                   0
# 67428       1                    0          0                   0
# 67441       0                    0          0                   0
# 68019       0                    0          0                   0
# 68129       0                    0          0                   0
#
#        Outside London the rest  Scotland, Newcastle  SouthEast  SouthWest
# 13                           0                    0          0          0
# 36                           0                    0          0          0
# 37                           0                    0          0          0
# 38                           0                    0          0          0
# 78                           0                    1          0          0
# ...                        ...                  ...        ...        ...
# 67191                        0                    0          0          0
# 67428                        0                    0          0          0
# 67441                        0                    1          0          0
# 68019                        1                    0          0          0
# 68129                        0                    0          0          0
#
# [265 rows x 29 columns]

# %%
list(sales_data_encoded.columns)
# Out:
# ['Date',
#  'Month',
#  'Quarter',
#  'Year',
#  'Qty',
#  'Product',
#  'Category',
#  'Pharmacy',
#  'Location',
#  'Pharmacy 1',
#  'Pharmacy 10',
#  'Pharmacy 2',
#  'Pharmacy 3',
#  'Pharmacy 5',
#  'Pharmacy 7',
#  'Pharmacy 8',
#  'Pharmacy 9',
#  'Injection 12',
#  'Injection 13',
#  'Brazil, USA, Blank, IE, Zimbabwe, Zurich',
#  'Ireland & Northern Ireland',
#  'London',
#  'NorthEast, Midlands',
#  'NorthWest',
#  'Outside London M25',
#  'Outside London the rest',
#  'Scotland, Newcastle',
#  'SouthEast',
#  'SouthWest']

# %%
# group the data by date and sum the quantities and category columns
sales_data_grouped = sales_data_encoded.groupby('Date').agg({
    'Qty': 'sum',
    'Pharmacy 1' : 'sum',
    'Pharmacy 2' : 'sum',
    'Pharmacy 3' : 'sum',
    'Pharmacy 5' : 'sum',
    'Pharmacy 7' : 'sum',
    'Pharmacy 8' : 'sum',
    'Pharmacy 9' : 'sum',
    'Pharmacy 10' : 'sum',
    'Injection 12' :'sum',
    'Injection 13' :'sum',
    'Brazil, USA, Blank, IE, Zimbabwe, Zurich' : 'sum',
    'Ireland & Northern Ireland' : 'sum',
    'London' : 'sum',
    'NorthEast, Midlands' : 'sum',
    'NorthWest' : 'sum',
    'Outside London M25' : 'sum',
    'Outside London the rest' : 'sum',
    'Scotland, Newcastle' : 'sum',
    'SouthEast' : 'sum',
    'SouthWest' : 'sum'
    					
})

# reset the index to make date a column again
sales_data_grouped = sales_data_grouped.reset_index()

# create lag features
sales_data_lagged = sales_data_grouped.copy()
for i in range(1, 8):
    sales_data_lagged[f'Qty_lag_{i}'] = sales_data_lagged['Qty'].shift(i)

#print(sales_data_lagged)

# remove rows with missing values
sales_data_lagged.dropna(inplace=True)


# split the data into training and testing sets
train_size = int(len(sales_data_lagged) * 0.8)
train_data = sales_data_lagged[:train_size]
test_data = sales_data_lagged[train_size:]

# %%
# train a random forest model

# model = RandomForestRegressor(n_estimators=100, max_depth=5)
# model.fit(train_data.iloc[:, 2:], train_data['Qty'])

criterion = ['friedman_mse', 'squared_error']
max_depth = [5, 10]
min_samples_leaf = [1, 2]
max_features = ['log2', 'sqrt']
loss = ['squared_error', 'huber', 'quantile']

random_grid_gbr = {
    'criterion' : criterion,
    'max_depth' : max_depth,
    'min_samples_leaf' : min_samples_leaf,
    'max_features' : max_features,
    'loss' : loss
}

gbr = GradientBoostingRegressor()
# gbr_random = RandomizedSearchCV(
#     estimator=gbr,
#     param_distributions=random_grid_gbr,
#     n_iter=10,
#     cv=5,
#     verbose=5,
#     random_state=0
# )
gbr_random = GridSearchCV(
    estimator=gbr,
    param_grid = random_grid_gbr,
    cv=5,
    verbose=5
)

# %%
gbr_random.fit(train_data.iloc[:, 2:], train_data['Qty'])


# make predictions for the test data
predictions = gbr_random.predict(test_data.iloc[:, 2:])
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV 1/5] END criterion=friedman_mse, loss=squared_error, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.606 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, loss=squared_error, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.743 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, loss=squared_error, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.457 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, loss=squared_error, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.677 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, loss=squared_error, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.653 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, loss=squared_error, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.689 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, loss=squared_error, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.562 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, loss=squared_error, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.379 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, loss=squared_error, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.594 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, loss=squared_error, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.489 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, loss=squared_error, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.587 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, loss=squared_error, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.733 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, loss=squared_error, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.284 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, loss=squared_error, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.669 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, loss=squared_error, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.432 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, loss=squared_error, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.673 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, loss=squared_error, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.744 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, loss=squared_error, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.326 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, loss=squared_error, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.741 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, loss=squared_error, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.516 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, loss=squared_error, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.479 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, loss=squared_error, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.654 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, loss=squared_error, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.507 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, loss=squared_error, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.625 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, loss=squared_error, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.604 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, loss=squared_error, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.601 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, loss=squared_error, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.758 total time=   0.5s
# [CV 3/5] END criterion=friedman_mse, loss=squared_error, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.360 total time=   0.3s
# [CV 4/5] END criterion=friedman_mse, loss=squared_error, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.768 total time=   0.2s
# [CV 5/5] END criterion=friedman_mse, loss=squared_error, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.419 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, loss=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.750 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, loss=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.791 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, loss=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.227 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, loss=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.639 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, loss=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.388 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, loss=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.663 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, loss=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.784 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, loss=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.199 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, loss=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.701 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, loss=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.623 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, loss=huber, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.676 total time=   0.4s
# [CV 2/5] END criterion=friedman_mse, loss=huber, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.492 total time=   0.3s
# [CV 3/5] END criterion=friedman_mse, loss=huber, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.479 total time=   0.4s
# [CV 4/5] END criterion=friedman_mse, loss=huber, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.644 total time=   1.6s
# [CV 5/5] END criterion=friedman_mse, loss=huber, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.324 total time=   0.5s
# [CV 1/5] END criterion=friedman_mse, loss=huber, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.690 total time=   0.3s
# [CV 2/5] END criterion=friedman_mse, loss=huber, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.764 total time=   0.3s
# [CV 3/5] END criterion=friedman_mse, loss=huber, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.431 total time=   0.3s
# [CV 4/5] END criterion=friedman_mse, loss=huber, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.566 total time=   0.3s
# [CV 5/5] END criterion=friedman_mse, loss=huber, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.351 total time=   0.3s
# [CV 1/5] END criterion=friedman_mse, loss=huber, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.609 total time=   0.5s
# [CV 2/5] END criterion=friedman_mse, loss=huber, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.711 total time=   0.4s
# [CV 3/5] END criterion=friedman_mse, loss=huber, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.532 total time=   0.4s
# [CV 4/5] END criterion=friedman_mse, loss=huber, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.533 total time=   0.5s
# [CV 5/5] END criterion=friedman_mse, loss=huber, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.507 total time=   0.5s
# [CV 1/5] END criterion=friedman_mse, loss=huber, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.420 total time=   0.3s
# [CV 2/5] END criterion=friedman_mse, loss=huber, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.648 total time=   0.6s
# [CV 3/5] END criterion=friedman_mse, loss=huber, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.355 total time=   0.4s
# [CV 4/5] END criterion=friedman_mse, loss=huber, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.598 total time=   0.2s
# [CV 5/5] END criterion=friedman_mse, loss=huber, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.395 total time=   0.2s
# [CV 1/5] END criterion=friedman_mse, loss=huber, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.331 total time=   0.7s
# [CV 2/5] END criterion=friedman_mse, loss=huber, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.626 total time=   1.1s
# [CV 3/5] END criterion=friedman_mse, loss=huber, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.454 total time=   0.7s
# [CV 4/5] END criterion=friedman_mse, loss=huber, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.537 total time=   0.9s
# [CV 5/5] END criterion=friedman_mse, loss=huber, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.677 total time=   0.8s
# [CV 1/5] END criterion=friedman_mse, loss=huber, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.572 total time=   0.3s
# [CV 2/5] END criterion=friedman_mse, loss=huber, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.715 total time=   0.3s
# [CV 3/5] END criterion=friedman_mse, loss=huber, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.265 total time=   0.3s
# [CV 4/5] END criterion=friedman_mse, loss=huber, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.587 total time=   0.3s
# [CV 5/5] END criterion=friedman_mse, loss=huber, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.640 total time=   0.4s
# [CV 1/5] END criterion=friedman_mse, loss=huber, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.666 total time=   0.7s
# [CV 2/5] END criterion=friedman_mse, loss=huber, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.617 total time=   0.6s
# [CV 3/5] END criterion=friedman_mse, loss=huber, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.223 total time=   0.8s
# [CV 4/5] END criterion=friedman_mse, loss=huber, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.558 total time=   0.8s
# [CV 5/5] END criterion=friedman_mse, loss=huber, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.380 total time=   0.8s
# [CV 1/5] END criterion=friedman_mse, loss=huber, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.704 total time=   0.3s
# [CV 2/5] END criterion=friedman_mse, loss=huber, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.672 total time=   0.3s
# [CV 3/5] END criterion=friedman_mse, loss=huber, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.511 total time=   0.3s
# [CV 4/5] END criterion=friedman_mse, loss=huber, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.540 total time=   0.4s
# [CV 5/5] END criterion=friedman_mse, loss=huber, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.119 total time=   0.3s
# [CV 1/5] END criterion=friedman_mse, loss=quantile, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.617 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, loss=quantile, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.392 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, loss=quantile, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.058 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, loss=quantile, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.560 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, loss=quantile, max_depth=5, max_features=log2, min_samples_leaf=1;, score=-0.038 total time=   0.2s
# [CV 1/5] END criterion=friedman_mse, loss=quantile, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.456 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, loss=quantile, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.316 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, loss=quantile, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.371 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, loss=quantile, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.583 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, loss=quantile, max_depth=5, max_features=log2, min_samples_leaf=2;, score=-0.445 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, loss=quantile, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.545 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, loss=quantile, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.390 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, loss=quantile, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.443 total time=   0.2s
# [CV 4/5] END criterion=friedman_mse, loss=quantile, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.513 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, loss=quantile, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=-0.127 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, loss=quantile, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.534 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, loss=quantile, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.168 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, loss=quantile, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.118 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, loss=quantile, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.590 total time=   0.2s
# [CV 5/5] END criterion=friedman_mse, loss=quantile, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=-0.288 total time=   0.2s
# [CV 1/5] END criterion=friedman_mse, loss=quantile, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.571 total time=   0.4s
# [CV 2/5] END criterion=friedman_mse, loss=quantile, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.320 total time=   0.3s
# [CV 3/5] END criterion=friedman_mse, loss=quantile, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.340 total time=   0.2s
# [CV 4/5] END criterion=friedman_mse, loss=quantile, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.553 total time=   0.2s
# [CV 5/5] END criterion=friedman_mse, loss=quantile, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.085 total time=   0.2s
# [CV 1/5] END criterion=friedman_mse, loss=quantile, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.639 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, loss=quantile, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.592 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, loss=quantile, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.286 total time=   0.2s
# [CV 4/5] END criterion=friedman_mse, loss=quantile, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.649 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, loss=quantile, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.341 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, loss=quantile, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.648 total time=   0.2s
# [CV 2/5] END criterion=friedman_mse, loss=quantile, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.303 total time=   0.2s
# [CV 3/5] END criterion=friedman_mse, loss=quantile, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.544 total time=   0.2s
# [CV 4/5] END criterion=friedman_mse, loss=quantile, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.624 total time=   0.3s
# [CV 5/5] END criterion=friedman_mse, loss=quantile, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.268 total time=   0.2s
# [CV 1/5] END criterion=friedman_mse, loss=quantile, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.535 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, loss=quantile, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.431 total time=   0.2s
# [CV 3/5] END criterion=friedman_mse, loss=quantile, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.249 total time=   0.2s
# [CV 4/5] END criterion=friedman_mse, loss=quantile, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.476 total time=   0.2s
# [CV 5/5] END criterion=friedman_mse, loss=quantile, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.141 total time=   0.2s
# [CV 1/5] END criterion=squared_error, loss=squared_error, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.462 total time=   0.0s
# [CV 2/5] END criterion=squared_error, loss=squared_error, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.626 total time=   0.0s
# [CV 3/5] END criterion=squared_error, loss=squared_error, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.379 total time=   0.0s
# [CV 4/5] END criterion=squared_error, loss=squared_error, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.684 total time=   0.0s
# [CV 5/5] END criterion=squared_error, loss=squared_error, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.400 total time=   0.0s
# [CV 1/5] END criterion=squared_error, loss=squared_error, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.708 total time=   0.0s
# [CV 2/5] END criterion=squared_error, loss=squared_error, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.832 total time=   0.0s
# [CV 3/5] END criterion=squared_error, loss=squared_error, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.191 total time=   0.0s
# [CV 4/5] END criterion=squared_error, loss=squared_error, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.684 total time=   0.0s
# [CV 5/5] END criterion=squared_error, loss=squared_error, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.555 total time=   0.0s
# [CV 1/5] END criterion=squared_error, loss=squared_error, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.420 total time=   0.0s
# [CV 2/5] END criterion=squared_error, loss=squared_error, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.668 total time=   0.1s
# [CV 3/5] END criterion=squared_error, loss=squared_error, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.453 total time=   0.0s
# [CV 4/5] END criterion=squared_error, loss=squared_error, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.632 total time=   0.0s
# [CV 5/5] END criterion=squared_error, loss=squared_error, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.334 total time=   0.0s
# [CV 1/5] END criterion=squared_error, loss=squared_error, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.674 total time=   0.0s
# [CV 2/5] END criterion=squared_error, loss=squared_error, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.666 total time=   0.0s
# [CV 3/5] END criterion=squared_error, loss=squared_error, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.324 total time=   0.0s
# [CV 4/5] END criterion=squared_error, loss=squared_error, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.720 total time=   0.0s
# [CV 5/5] END criterion=squared_error, loss=squared_error, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.469 total time=   0.0s
# [CV 1/5] END criterion=squared_error, loss=squared_error, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.354 total time=   0.0s
# [CV 2/5] END criterion=squared_error, loss=squared_error, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.739 total time=   0.0s
# [CV 3/5] END criterion=squared_error, loss=squared_error, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.567 total time=   0.0s
# [CV 4/5] END criterion=squared_error, loss=squared_error, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.699 total time=   0.0s
# [CV 5/5] END criterion=squared_error, loss=squared_error, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.543 total time=   0.0s
# [CV 1/5] END criterion=squared_error, loss=squared_error, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.289 total time=   0.0s
# [CV 2/5] END criterion=squared_error, loss=squared_error, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.650 total time=   0.0s
# [CV 3/5] END criterion=squared_error, loss=squared_error, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.331 total time=   0.0s
# [CV 4/5] END criterion=squared_error, loss=squared_error, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.700 total time=   0.0s
# [CV 5/5] END criterion=squared_error, loss=squared_error, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.615 total time=   0.0s
# [CV 1/5] END criterion=squared_error, loss=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.679 total time=   0.0s
# [CV 2/5] END criterion=squared_error, loss=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.722 total time=   0.0s
# [CV 3/5] END criterion=squared_error, loss=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.314 total time=   0.0s
# [CV 4/5] END criterion=squared_error, loss=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.587 total time=   0.0s
# [CV 5/5] END criterion=squared_error, loss=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.491 total time=   0.0s
# [CV 1/5] END criterion=squared_error, loss=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.508 total time=   0.0s
# [CV 2/5] END criterion=squared_error, loss=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.836 total time=   0.0s
# [CV 3/5] END criterion=squared_error, loss=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.334 total time=   0.0s
# [CV 4/5] END criterion=squared_error, loss=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.584 total time=   0.0s
# [CV 5/5] END criterion=squared_error, loss=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.515 total time=   0.0s
# [CV 1/5] END criterion=squared_error, loss=huber, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.648 total time=   0.4s
# [CV 2/5] END criterion=squared_error, loss=huber, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.791 total time=   0.3s
# [CV 3/5] END criterion=squared_error, loss=huber, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.348 total time=   0.3s
# [CV 4/5] END criterion=squared_error, loss=huber, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.595 total time=   0.7s
# [CV 5/5] END criterion=squared_error, loss=huber, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.517 total time=   0.8s
# [CV 1/5] END criterion=squared_error, loss=huber, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.670 total time=   0.4s
# [CV 2/5] END criterion=squared_error, loss=huber, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.686 total time=   0.4s
# [CV 3/5] END criterion=squared_error, loss=huber, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.288 total time=   0.3s
# [CV 4/5] END criterion=squared_error, loss=huber, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.517 total time=   0.4s
# [CV 5/5] END criterion=squared_error, loss=huber, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.386 total time=   0.4s
# [CV 1/5] END criterion=squared_error, loss=huber, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.526 total time=   0.5s
# [CV 2/5] END criterion=squared_error, loss=huber, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.532 total time=   0.5s
# [CV 3/5] END criterion=squared_error, loss=huber, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.345 total time=   0.6s
# [CV 4/5] END criterion=squared_error, loss=huber, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.664 total time=   0.6s
# [CV 5/5] END criterion=squared_error, loss=huber, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.556 total time=   0.5s
# [CV 1/5] END criterion=squared_error, loss=huber, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.546 total time=   0.3s
# [CV 2/5] END criterion=squared_error, loss=huber, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.669 total time=   0.5s
# [CV 3/5] END criterion=squared_error, loss=huber, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.290 total time=   0.3s
# [CV 4/5] END criterion=squared_error, loss=huber, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.465 total time=   0.3s
# [CV 5/5] END criterion=squared_error, loss=huber, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.382 total time=   0.3s
# [CV 1/5] END criterion=squared_error, loss=huber, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.522 total time=   0.8s
# [CV 2/5] END criterion=squared_error, loss=huber, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.696 total time=   0.9s
# [CV 3/5] END criterion=squared_error, loss=huber, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.304 total time=   0.7s
# [CV 4/5] END criterion=squared_error, loss=huber, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.578 total time=   0.7s
# [CV 5/5] END criterion=squared_error, loss=huber, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.428 total time=   2.5s
# [CV 1/5] END criterion=squared_error, loss=huber, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.504 total time=   0.3s
# [CV 2/5] END criterion=squared_error, loss=huber, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.761 total time=   0.3s
# [CV 3/5] END criterion=squared_error, loss=huber, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.537 total time=   1.5s
# [CV 4/5] END criterion=squared_error, loss=huber, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.554 total time=   1.0s
# [CV 5/5] END criterion=squared_error, loss=huber, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.656 total time=   0.5s
# [CV 1/5] END criterion=squared_error, loss=huber, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.640 total time=   0.9s
# [CV 2/5] END criterion=squared_error, loss=huber, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.758 total time=   0.9s
# [CV 3/5] END criterion=squared_error, loss=huber, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.366 total time=   1.0s
# [CV 4/5] END criterion=squared_error, loss=huber, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.590 total time=   1.3s
# [CV 5/5] END criterion=squared_error, loss=huber, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.628 total time=   1.2s
# [CV 1/5] END criterion=squared_error, loss=huber, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.567 total time=   0.7s
# [CV 2/5] END criterion=squared_error, loss=huber, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.673 total time=   0.5s
# [CV 3/5] END criterion=squared_error, loss=huber, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.349 total time=   0.4s
# [CV 4/5] END criterion=squared_error, loss=huber, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.527 total time=   0.3s
# [CV 5/5] END criterion=squared_error, loss=huber, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.667 total time=   0.4s
# [CV 1/5] END criterion=squared_error, loss=quantile, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.377 total time=   0.2s
# [CV 2/5] END criterion=squared_error, loss=quantile, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.441 total time=   0.2s
# [CV 3/5] END criterion=squared_error, loss=quantile, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.415 total time=   0.1s
# [CV 4/5] END criterion=squared_error, loss=quantile, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.561 total time=   0.2s
# [CV 5/5] END criterion=squared_error, loss=quantile, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.049 total time=   0.2s
# [CV 1/5] END criterion=squared_error, loss=quantile, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.420 total time=   0.2s
# [CV 2/5] END criterion=squared_error, loss=quantile, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.266 total time=   0.2s
# [CV 3/5] END criterion=squared_error, loss=quantile, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.331 total time=   0.2s
# [CV 4/5] END criterion=squared_error, loss=quantile, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.614 total time=   0.1s
# [CV 5/5] END criterion=squared_error, loss=quantile, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.130 total time=   0.1s
# [CV 1/5] END criterion=squared_error, loss=quantile, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.574 total time=   0.1s
# [CV 2/5] END criterion=squared_error, loss=quantile, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.376 total time=   0.1s
# [CV 3/5] END criterion=squared_error, loss=quantile, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.548 total time=   0.2s
# [CV 4/5] END criterion=squared_error, loss=quantile, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.544 total time=   0.1s
# [CV 5/5] END criterion=squared_error, loss=quantile, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.278 total time=   0.2s
# [CV 1/5] END criterion=squared_error, loss=quantile, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.354 total time=   0.2s
# [CV 2/5] END criterion=squared_error, loss=quantile, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.365 total time=   0.1s
# [CV 3/5] END criterion=squared_error, loss=quantile, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.511 total time=   0.1s
# [CV 4/5] END criterion=squared_error, loss=quantile, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.467 total time=   0.2s
# [CV 5/5] END criterion=squared_error, loss=quantile, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=-0.021 total time=   0.2s
# [CV 1/5] END criterion=squared_error, loss=quantile, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.624 total time=   0.2s
# [CV 2/5] END criterion=squared_error, loss=quantile, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.695 total time=   0.2s
# [CV 3/5] END criterion=squared_error, loss=quantile, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.514 total time=   0.2s
# [CV 4/5] END criterion=squared_error, loss=quantile, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.528 total time=   0.2s
# [CV 5/5] END criterion=squared_error, loss=quantile, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.285 total time=   0.5s
# [CV 1/5] END criterion=squared_error, loss=quantile, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.432 total time=   0.2s
# [CV 2/5] END criterion=squared_error, loss=quantile, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.222 total time=   0.2s
# [CV 3/5] END criterion=squared_error, loss=quantile, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.372 total time=   0.2s
# [CV 4/5] END criterion=squared_error, loss=quantile, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.615 total time=   0.1s
# [CV 5/5] END criterion=squared_error, loss=quantile, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.031 total time=   0.2s
# [CV 1/5] END criterion=squared_error, loss=quantile, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.632 total time=   0.3s
# [CV 2/5] END criterion=squared_error, loss=quantile, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.417 total time=   0.2s
# [CV 3/5] END criterion=squared_error, loss=quantile, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.541 total time=   0.2s
# [CV 4/5] END criterion=squared_error, loss=quantile, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.612 total time=   0.1s
# [CV 5/5] END criterion=squared_error, loss=quantile, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=-0.002 total time=   0.2s
# [CV 1/5] END criterion=squared_error, loss=quantile, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.395 total time=   0.1s
# [CV 2/5] END criterion=squared_error, loss=quantile, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.405 total time=   0.1s
# [CV 3/5] END criterion=squared_error, loss=quantile, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.373 total time=   0.1s
# [CV 4/5] END criterion=squared_error, loss=quantile, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.658 total time=   0.1s
# [CV 5/5] END criterion=squared_error, loss=quantile, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=-0.145 total time=   0.2s

# %%
# calculate the root mean squared error (RMSE) of the predictions
rmse = ((predictions - test_data['Qty']) ** 2).mean() ** 0.5
print('RMSE:', rmse)

# calculate the mean squared error
mse = mean_squared_error(test_data['Qty'], predictions)
print('MSE:', mse)

# calculate the r2 score
r2_score = r2_score(test_data['Qty'], predictions)
print('R^2 Score:', r2_score)

# calculate explained variance score
explained_variance_score = explained_variance_score(test_data['Qty'], predictions)
print('Explained Variance Score:', explained_variance_score)

# calculate max error
max_error = max_error(test_data['Qty'], predictions)
print('Max Error:', max_error)


print([test_data['Date'].values, test_data['Qty'].values, predictions])
# Out:
# RMSE: 2.9543002283279707
# MSE: 8.7278898390987
# R^2 Score: 0.2942519699484786
# Explained Variance Score: 0.3340445456761336
# Max Error: 6.65622554935727
# [array(['1-7-2021', '1-8-2016', '1-8-2017', '1-8-2018', '1-8-2019',
#        '1-8-2020', '1-8-2021', '1-9-2016', '1-9-2017', '1-9-2018',
#        '1-9-2019', '1-9-2020', '1-9-2021'], dtype=object), array([11,  4,  1,  3,  6,  7,  6,  3,  3,  5,  2,  4, 14], dtype=int64), array([8.97200584, 3.10705875, 1.57159554, 6.1069909 , 7.04257282,
#        8.4584737 , 6.19460556, 2.15856133, 4.25281921, 9.305537  ,
#        6.6019907 , 7.00358017, 7.34377445])]

# %%
sales_data_lagged['predicted_quantity'] = pd.Series(predictions, index=test_data.index)
sales_data_lagged= sales_data_lagged.sort_values(by=['Date'])

# plot the actual and predicted quantities against date
plt.plot(sales_data_lagged['Date'], sales_data_lagged['Qty'], label='Actual')
plt.plot(sales_data_lagged['Date'], sales_data_lagged['predicted_quantity'], label='Predicted')
plt.xlabel('Date')
plt.ylabel('Qty')
plt.title('Sales Data Forecasting')
plt.legend()
plt.show()

# %%
gbr_random.best_params_
# Out:
# {'criterion': 'friedman_mse',
#  'loss': 'squared_error',
#  'max_depth': 5,
#  'max_features': 'log2',
#  'min_samples_leaf': 1}

# %%
matrix_data = np.column_stack((test_data['Qty'].values, predictions))

# plot the matrix using seaborn's heatmap function
sns.heatmap(matrix_data, annot=True, fmt='.1f', cmap='coolwarm', linewidths=.5, cbar=False)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title(f'Actual vs. Predicted Sales Data (RMSE={rmse:.2f})')
plt.show()
