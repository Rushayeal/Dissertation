# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import r2_score, explained_variance_score, max_error, mean_squared_error
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split

# load the sales data set
sales_data = pd.read_csv('../../../Data/SalesData.csv')
sales_data.head()

sales_data = sales_data[sales_data['Category'] == 'Needles'] 

pharmacy_onehot = pd.get_dummies(sales_data['Pharmacy'])

# concatenate the one-hot encoded categories with the original data
sales_data_encoded2 = pd.concat([sales_data, pharmacy_onehot], axis=1)

product_onehot = pd.get_dummies(sales_data['Product'])

# concatenate the one-hot encoded categories with the original data
sales_data_encoded3 = pd.concat([sales_data_encoded2, product_onehot], axis=1)

product_onehot = pd.get_dummies(sales_data['Location'])

# concatenate the one-hot encoded categories with the original data
sales_data_encoded = pd.concat([sales_data_encoded3, product_onehot], axis=1)

sales_data_encoded
# Out:
#             Date  Month  Quarter  Year  Qty               Product Category  \
# 14     1-12-2015     12        4  2015    1   Mesotherapy Needles  Needles
# 39      1-1-2016      1        1  2016    1   Mesotherapy Needles  Needles
# 40      1-1-2016      1        1  2016    1   Mesotherapy Needles  Needles
# 41      1-1-2016      1        1  2016    1   Mesotherapy Needles  Needles
# 79      1-2-2016      2        1  2016    1   Mesotherapy Needles  Needles
# ...          ...    ...      ...   ...  ...                   ...      ...
# 68074   1-3-2022      3        1  2022    1  Skin Booster Needles  Needles
# 68087   1-3-2022      3        1  2022    6  Skin Booster Needles  Needles
# 68092   1-3-2022      3        1  2022    1  Skin Booster Needles  Needles
# 68130   1-3-2022      3        1  2022    1   Mesotherapy Needles  Needles
# 68154   1-3-2022      3        1  2022    1  Skin Booster Needles  Needles
#
#           Pharmacy                    Location  Pharmacy 10  ...  \
# 14      Pharmacy 2          Outside London M25            0  ...
# 39      Pharmacy 2                   NorthWest            0  ...
# 40      Pharmacy 2          Outside London M25            0  ...
# 41      Pharmacy 2          Outside London M25            0  ...
# 79      Pharmacy 2         Scotland, Newcastle            0  ...
# ...            ...                         ...          ...  ...
# 68074   Pharmacy 3                   SouthEast            0  ...
# 68087  Pharmacy 10     Outside London the rest            1  ...
# 68092  Pharmacy 10  Ireland & Northern Ireland            1  ...
# 68130  Pharmacy 10  Ireland & Northern Ireland            1  ...
# 68154  Pharmacy 10  Ireland & Northern Ireland            1  ...
#
#        Brazil, USA, Blank, IE, Zimbabwe, Zurich  Ireland & Northern Ireland  \
# 14                                            0                           0
# 39                                            0                           0
# 40                                            0                           0
# 41                                            0                           0
# 79                                            0                           0
# ...                                         ...                         ...
# 68074                                         0                           0
# 68087                                         0                           0
# 68092                                         0                           1
# 68130                                         0                           1
# 68154                                         0                           1
#
#        London  NorthEast, Midlands  NorthWest  Outside London M25  \
# 14          0                    0          0                   1
# 39          0                    0          1                   0
# 40          0                    0          0                   1
# 41          0                    0          0                   1
# 79          0                    0          0                   0
# ...       ...                  ...        ...                 ...
# 68074       0                    0          0                   0
# 68087       0                    0          0                   0
# 68092       0                    0          0                   0
# 68130       0                    0          0                   0
# 68154       0                    0          0                   0
#
#        Outside London the rest  Scotland, Newcastle  SouthEast  SouthWest
# 14                           0                    0          0          0
# 39                           0                    0          0          0
# 40                           0                    0          0          0
# 41                           0                    0          0          0
# 79                           0                    1          0          0
# ...                        ...                  ...        ...        ...
# 68074                        0                    0          1          0
# 68087                        1                    0          0          0
# 68092                        0                    0          0          0
# 68130                        0                    0          0          0
# 68154                        0                    0          0          0
#
# [465 rows x 27 columns]

# %%
list(sales_data_encoded.columns)
# Out:
# ['Date',
#  'Month',
#  'Quarter',
#  'Year',
#  'Qty',
#  'Product',
#  'Category',
#  'Pharmacy',
#  'Location',
#  'Pharmacy 10',
#  'Pharmacy 2',
#  'Pharmacy 3',
#  'Pharmacy 4',
#  'Pharmacy 5',
#  'Pharmacy 9',
#  'Mesotherapy Needles',
#  'Skin Booster Needles',
#  'Brazil, USA, Blank, IE, Zimbabwe, Zurich',
#  'Ireland & Northern Ireland',
#  'London',
#  'NorthEast, Midlands',
#  'NorthWest',
#  'Outside London M25',
#  'Outside London the rest',
#  'Scotland, Newcastle',
#  'SouthEast',
#  'SouthWest']

# %%
# group the data by date and sum the quantities and category columns
sales_data_grouped = sales_data_encoded.groupby('Date').agg({
    'Qty': 'sum',
    'Pharmacy 2' : 'sum',
    'Pharmacy 3' : 'sum',
    'Pharmacy 4' : 'sum',
    'Pharmacy 5' : 'sum',
    'Pharmacy 9' : 'sum',
    'Pharmacy 10' : 'sum',
    'Mesotherapy Needles' : 'sum',
    'Skin Booster Needles' : 'sum',
    'Brazil, USA, Blank, IE, Zimbabwe, Zurich' : 'sum',
    'Ireland & Northern Ireland' : 'sum',
    'London' : 'sum',
    'NorthEast, Midlands' : 'sum',
    'NorthWest' : 'sum',
    'Outside London M25' : 'sum',
    'Outside London the rest' : 'sum',
    'Scotland, Newcastle' : 'sum',
    'SouthEast' : 'sum',
    'SouthWest' : 'sum'
    					
})

# reset the index to make date a column again
sales_data_grouped = sales_data_grouped.reset_index()

# create lag features
sales_data_lagged = sales_data_grouped.copy()
for i in range(1, 8):
    sales_data_lagged[f'Qty_lag_{i}'] = sales_data_lagged['Qty'].shift(i)

#print(sales_data_lagged)

# remove rows with missing values
sales_data_lagged.dropna(inplace=True)


# split the data into training and testing sets
train_size = int(len(sales_data_lagged) * 0.8)
train_data = sales_data_lagged[:train_size]
test_data = sales_data_lagged[train_size:]

# %%
# train a random forest model

# model = RandomForestRegressor(n_estimators=100, max_depth=5)
# model.fit(train_data.iloc[:, 2:], train_data['Qty'])

criterion = ['squared_error', 'friedman_mse', 'poisson']
max_depth = [5, 10]
min_samples_leaf = [1, 2]
max_features = ['log2', 'sqrt']

random_grid_rfr = {
    'criterion' : criterion,
    'max_depth' : max_depth,
    'min_samples_leaf' : min_samples_leaf,
    'max_features' : max_features
}
# rfr = RandomForestRegressor()
# rfr_random = RandomizedSearchCV(
#     estimator=rfr,
#     param_distributions=random_grid_rfr,
#     n_iter=10,
#     cv=5,
#     verbose=5,
#     random_state=0
# )
rfr = RandomForestRegressor()
rfr_random = GridSearchCV(
    estimator=rfr,
    param_grid=random_grid_rfr,
    cv=5,
    verbose=5
)

# %%
rfr_random.fit(train_data.iloc[:, 2:], train_data['Qty'])


# make predictions for the test data
predictions = rfr_random.predict(test_data.iloc[:, 2:])
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 1/5] END criterion=squared_error, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.798 total time=   0.1s
# [CV 2/5] END criterion=squared_error, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.668 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.935 total time=   0.1s
# [CV 4/5] END criterion=squared_error, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.824 total time=   0.1s
# [CV 5/5] END criterion=squared_error, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.482 total time=   0.1s
# [CV 1/5] END criterion=squared_error, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.843 total time=   0.1s
# [CV 2/5] END criterion=squared_error, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.787 total time=   0.2s
# [CV 3/5] END criterion=squared_error, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.897 total time=   0.2s
# [CV 4/5] END criterion=squared_error, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.816 total time=   0.2s
# [CV 5/5] END criterion=squared_error, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.443 total time=   0.2s
# [CV 1/5] END criterion=squared_error, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.805 total time=   0.1s
# [CV 2/5] END criterion=squared_error, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.688 total time=   0.2s
# [CV 3/5] END criterion=squared_error, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.914 total time=   0.1s
# [CV 4/5] END criterion=squared_error, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.834 total time=   0.2s
# [CV 5/5] END criterion=squared_error, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.448 total time=   0.1s
# [CV 1/5] END criterion=squared_error, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.904 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.751 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.902 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.807 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.433 total time=   0.1s
# [CV 1/5] END criterion=squared_error, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.780 total time=   0.1s
# [CV 2/5] END criterion=squared_error, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.725 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.842 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.777 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.470 total time=   0.1s
# [CV 1/5] END criterion=squared_error, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.820 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.726 total time=   0.1s
# [CV 3/5] END criterion=squared_error, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.883 total time=   0.1s
# [CV 4/5] END criterion=squared_error, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.803 total time=   0.1s
# [CV 5/5] END criterion=squared_error, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.437 total time=   0.1s
# [CV 1/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.832 total time=   0.1s
# [CV 2/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.741 total time=   0.1s
# [CV 3/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.924 total time=   0.1s
# [CV 4/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.840 total time=   0.1s
# [CV 5/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.483 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.883 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.738 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.882 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.832 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.446 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.810 total time=   0.2s
# [CV 2/5] END criterion=friedman_mse, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.593 total time=   0.4s
# [CV 3/5] END criterion=friedman_mse, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.911 total time=   0.2s
# [CV 4/5] END criterion=friedman_mse, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.795 total time=   0.3s
# [CV 5/5] END criterion=friedman_mse, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.487 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.876 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.791 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.858 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.826 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.448 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.801 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.583 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.919 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.797 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.465 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.826 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.786 total time=   0.2s
# [CV 3/5] END criterion=friedman_mse, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.897 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.806 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.416 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.790 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.738 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.926 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.828 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.435 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.859 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.787 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.901 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.799 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.446 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.803 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.661 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.941 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.757 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.410 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.854 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.718 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.900 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.785 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.485 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.752 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.670 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.891 total time=   0.1s
# [CV 4/5] END criterion=poisson, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.873 total time=   0.1s
# [CV 5/5] END criterion=poisson, max_depth=5, max_features=log2, min_samples_leaf=1;, score=0.454 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.816 total time=   0.1s
# [CV 2/5] END criterion=poisson, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.803 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.890 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.849 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=5, max_features=log2, min_samples_leaf=2;, score=0.453 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.766 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.734 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.872 total time=   0.1s
# [CV 4/5] END criterion=poisson, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.842 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=5, max_features=sqrt, min_samples_leaf=1;, score=0.471 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.830 total time=   0.1s
# [CV 2/5] END criterion=poisson, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.755 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.794 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.766 total time=   0.1s
# [CV 5/5] END criterion=poisson, max_depth=5, max_features=sqrt, min_samples_leaf=2;, score=0.433 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.778 total time=   0.1s
# [CV 2/5] END criterion=poisson, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.680 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.919 total time=   0.1s
# [CV 4/5] END criterion=poisson, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.873 total time=   0.1s
# [CV 5/5] END criterion=poisson, max_depth=10, max_features=log2, min_samples_leaf=1;, score=0.479 total time=   0.1s
# [CV 1/5] END criterion=poisson, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.837 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.758 total time=   0.1s
# [CV 3/5] END criterion=poisson, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.884 total time=   0.1s
# [CV 4/5] END criterion=poisson, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.775 total time=   0.1s
# [CV 5/5] END criterion=poisson, max_depth=10, max_features=log2, min_samples_leaf=2;, score=0.456 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.762 total time=   0.1s
# [CV 2/5] END criterion=poisson, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.735 total time=   0.2s
# [CV 3/5] END criterion=poisson, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.916 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.817 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=10, max_features=sqrt, min_samples_leaf=1;, score=0.455 total time=   0.1s
# [CV 1/5] END criterion=poisson, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.825 total time=   0.3s
# [CV 2/5] END criterion=poisson, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.734 total time=   0.1s
# [CV 3/5] END criterion=poisson, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.825 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.813 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=10, max_features=sqrt, min_samples_leaf=2;, score=0.471 total time=   0.1s

# %%
# calculate the root mean squared error (RMSE) of the predictions
rmse = ((predictions - test_data['Qty']) ** 2).mean() ** 0.5
print('RMSE:', rmse)

# calculate the mean squared error
mse = mean_squared_error(test_data['Qty'], predictions)
print('MSE:', mse)

# calculate the r2 score
r2_score = r2_score(test_data['Qty'], predictions)
print('R^2 Score:', r2_score)

# calculate explained variance score
explained_variance_score = explained_variance_score(test_data['Qty'], predictions)
print('Explained Variance Score:', explained_variance_score)

# calculate max error
max_error = max_error(test_data['Qty'], predictions)
print('Max Error:', max_error)


print([test_data['Date'].values, test_data['Qty'].values, predictions])
# Out:
# RMSE: 14.787879838800436
# MSE: 218.68139012680038
# R^2 Score: 0.7327903725285176
# Explained Variance Score: 0.7400528740377068
# Max Error: 49.17
# [array(['1-7-2020', '1-7-2021', '1-8-2016', '1-8-2017', '1-8-2018',
#        '1-8-2019', '1-8-2020', '1-8-2021', '1-9-2018', '1-9-2019',
#        '1-9-2020', '1-9-2021'], dtype=object), array([ 17,  35,   2,   1,   3,  12,  22,  36,   1,  12, 105,  50],
#       dtype=int64), array([24.47      , 37.27      ,  3.044     ,  5.74822222,  4.8175    ,
#        12.58      , 31.01      , 30.02      ,  1.435     , 11.39      ,
#        55.83      , 49.13      ])]

# %%
sales_data_lagged['predicted_quantity'] = pd.Series(predictions, index=test_data.index)
sales_data_lagged= sales_data_lagged.sort_values(by=['Date'])

# plot the actual and predicted quantities against date
plt.plot(sales_data_lagged['Date'], sales_data_lagged['Qty'], label='Actual')
plt.plot(sales_data_lagged['Date'], sales_data_lagged['predicted_quantity'], label='Predicted')
plt.xlabel('Date')
plt.ylabel('Qty')
plt.title('Sales Data Forecasting')
plt.legend()
plt.show()

# %%
rfr_random.best_params_
# Out:
# {'criterion': 'squared_error',
#  'max_depth': 10,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1}

# %%
matrix_data = np.column_stack((test_data['Qty'].values, predictions))

# plot the matrix using seaborn's heatmap function
sns.heatmap(matrix_data, annot=True, fmt='.1f', cmap='coolwarm', linewidths=.5, cbar=False)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title(f'Actual vs. Predicted Sales Data (RMSE={rmse:.2f})')
plt.show()
